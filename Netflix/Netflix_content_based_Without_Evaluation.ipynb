# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
pd.set_option('display.max_columns', 200)

# %% [markdown]
# ### Reading Datasets

# %%
movies = pd.read_csv('movies.csv')
print("movies.csv")
display(movies.head(1))

reviews = pd.read_csv('reviews.csv')
print("reviews.csv")
display(reviews.head(1))

search_logs = pd.read_csv('search_logs.csv')
print("search_logs.csv")
display(search_logs.head(1))

users = pd.read_csv('users.csv')
print("users.csv")
display(users.head(1))

watch_history = pd.read_csv('watch_history.csv')
print("watch_history.csv")
display(watch_history.head(1))
# Out:
# movies.csv
#      movie_id          title     content_type genre_primary genre_secondary  \
# 0  movie_0001  Dragon Legend  Stand-up Comedy       History        Thriller
#
#    release_year  duration_minutes rating language country_of_origin  \
# 0          2014              35.0   TV-Y   French             Japan
#
#    imdb_rating  production_budget  box_office_revenue  number_of_seasons  \
# 0          NaN                NaN                 NaN                NaN
#
#    number_of_episodes  is_netflix_original added_to_platform  content_warning
# 0                 NaN                False        2023-08-07            False
# reviews.csv
#        review_id     user_id    movie_id  rating review_date device_type  \
# 0  review_000001  user_07066  movie_0360       4  2025-03-29      Mobile
#
#    is_verified_watch  helpful_votes  total_votes  \
# 0              False            3.0          5.0
#
#                                  review_text sentiment  sentiment_score
# 0  Fantastic cinematography and plot twists.  positive            0.711
# search_logs.csv
#        search_id     user_id    search_query search_date  results_returned  \
# 0  search_000001  user_09864  classic movies  2024-03-22                20
#
#    clicked_result_position device_type  search_duration_seconds  had_typo  \
# 0                      2.0      Tablet                     12.4     False
#
#    used_filters location_country
# 0         False           Canada
# users.csv
#       user_id                     email first_name last_name   age gender  \
# 0  user_00001  figueroajohn@example.org      Erica     Garza  43.0   Male
#
#   country state_province                city subscription_plan  \
# 0     USA  Massachusetts  North Jefferyhaven             Basic
#
#   subscription_start_date  is_active  monthly_spend primary_device  \
# 0              2024-04-08       True          36.06         Laptop
#
#    household_size                  created_at
# 0             1.0  2023-04-01 14:40:50.540242
# watch_history.csv
#        session_id     user_id    movie_id  watch_date device_type  \
# 0  session_000001  user_07271  movie_0511  2025-11-13      Tablet
#
#    watch_duration_minutes  progress_percentage     action quality  \
# 0                    63.9                 34.6  completed      HD
#
#   location_country  is_download  user_rating
# 0              USA        False          NaN

# %%
display(movies.shape)
display(reviews.shape)
display(search_logs.shape)
display(users.shape)
display(watch_history.shape)
# Out:
# (1040, 18)
# (15450, 12)
# (26500, 11)
# (10300, 16)
# (105000, 12)

# %% [markdown]
# ### Content based

# %%
#Getting what user has seen
df = watch_history.merge(movies, on = 'movie_id', how = 'left')
print(df.shape)
# Out:
# (109237, 29)

# %%
df1 = df.drop_duplicates()
print(df1.shape)
# Out:
# (100000, 29)

# %%
df1
# Out:
#             session_id     user_id    movie_id  watch_date device_type  \
# 0       session_000001  user_07271  movie_0511  2025-11-13      Tablet
# 1       session_000002  user_00861  movie_0588  2025-02-26      Laptop
# 2       session_000003  user_05391  movie_0694  2024-12-15     Desktop
# 3       session_000004  user_05192  movie_0234  2024-09-30     Desktop
# 4       session_000005  user_05735  movie_0390  2024-08-04      Tablet
# ...                ...         ...         ...         ...         ...
# 104018  session_099996  user_09970  movie_0637  2024-08-02      Laptop
# 104019  session_099997  user_00534  movie_0386  2024-01-15      Laptop
# 104020  session_099998  user_08894  movie_0639  2024-07-18    Smart TV
# 104021  session_099999  user_02303  movie_0581  2024-08-06     Desktop
# 104022  session_100000  user_02665  movie_0623  2025-03-30      Tablet
#
#         watch_duration_minutes  progress_percentage     action quality  \
# 0                         63.9                 34.6  completed      HD
# 1                        120.1                 44.2    started      HD
# 2                        572.1                 84.7    started      HD
# 3                        395.3                 89.9  completed      SD
# 4                         14.6                  6.2  completed      HD
# ...                        ...                  ...        ...     ...
# 104018                     4.0                 20.0  completed      4K
# 104019                    48.0                  NaN     paused      HD
# 104020                    15.3                 34.3    started      SD
# 104021                    32.2                 40.6  completed      HD
# 104022                    25.2                 95.1     paused      HD
#
#        location_country  is_download  user_rating            title  \
# 0                   USA        False          NaN  Dragon Princess
# 1                   USA        False          NaN      Queen Queen
# 2                Canada        False          1.0      Kingdom Day
# 3                   USA        False          5.0          An Fire
# 4                   USA        False          NaN        Old Night
# ...                 ...          ...          ...              ...
# 104018              USA        False          NaN       Old Battle
# 104019           Canada        False          3.0        Hero Hero
# 104020              USA        False          NaN       Quest Fire
# 104021              USA        False          3.0      Ice Kingdom
# 104022              USA        False          NaN       Family Day
#
#            content_type genre_primary genre_secondary  release_year  \
# 0                 Movie         Music             NaN          2018
# 1                 Movie        Sci-Fi             NaN          1997
# 2                 Movie        Action             NaN          1996
# 3             TV Series        Horror           Music          1991
# 4                 Movie       Fantasy          Sci-Fi          2004
# ...                 ...           ...             ...           ...
# 104018        TV Series        Family         History          2006
# 104019  Stand-up Comedy           War       Adventure          2015
# 104020   Limited Series         Sport             War          1996
# 104021      Documentary        Sci-Fi             War          2016
# 104022  Stand-up Comedy        Family             NaN          2013
#
#         duration_minutes rating  language country_of_origin  imdb_rating  \
# 0                   92.0      G   Spanish       South Korea          5.2
# 1                  122.0   TV-Y   English             India          2.5
# 2                   89.0     PG   English                UK          5.9
# 3                   58.0  TV-Y7  Japanese       South Korea          8.5
# 4                   94.0  TV-Y7   Spanish               USA          2.7
# ...                  ...    ...       ...               ...          ...
# 104018              58.0  TV-MA   English               USA          5.5
# 104019              42.0     PG   English               USA          8.6
# 104020              68.0  TV-Y7   English            Canada          4.8
# 104021             111.0   TV-Y   English               USA          2.7
# 104022              54.0     PG   English               USA          9.3
#
#         production_budget  box_office_revenue  number_of_seasons  \
# 0               1893934.0           1115568.0                NaN
# 1                447581.0         391734641.0                NaN
# 2               6072218.0          37239804.0                NaN
# 3                     NaN                 NaN                NaN
# 4               1231347.0           2483539.0                NaN
# ...                   ...                 ...                ...
# 104018                NaN                 NaN                1.0
# 104019                NaN                 NaN                NaN
# 104020                NaN                 NaN               11.0
# 104021                NaN                 NaN                NaN
# 104022                NaN                 NaN                NaN
#
#         number_of_episodes  is_netflix_original added_to_platform  \
# 0                      NaN                False        2022-06-04
# 1                      NaN                False        2023-09-15
# 2                      NaN                False        2023-01-14
# 3                    178.0                False        2021-01-11
# 4                      NaN                False        2024-07-05
# ...                    ...                  ...               ...
# 104018                83.0                 True        2021-10-03
# 104019                 NaN                False        2020-10-11
# 104020                37.0                 True        2021-05-03
# 104021                 NaN                False        2023-07-19
# 104022                 NaN                False        2023-08-08
#
#         content_warning
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 104018            False
# 104019            False
# 104020            False
# 104021             True
# 104022            False
#
# [100000 rows x 29 columns]

# %% [markdown]
# ### Getting Features

# %%
df1.language.value_counts()
# Out:
# language
# English     58465
# Spanish      9853
# French       6601
# Hindi        5746
# Japanese     5277
# Italian      5162
# Korean       4877
# German       4019
# Name: count, dtype: int64

# %% [markdown]
# ### Processing Text Features

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

#applying tf-idf - Term Frequency Inverse Document Frequency which basically gives more score to rare words as they are rare and more discriminative power for 
#similarity search

tf = TfidfVectorizer()

ohe = OneHotEncoder()
df1['device_type'] = df1['device_type'].fillna('')
device_type_ft = ohe.fit_transform(df1[['device_type']])

df1['quality'] = df1['quality'].fillna('')
quality_type_ft = ohe.fit_transform(df1[['quality']])

df1['genre_primary'] = df1['genre_primary'].fillna('')
genre_primary_ft = tf.fit_transform(df1['genre_primary'])

df1['genre_secondary'] = df1['genre_secondary'].fillna('')
genre_secondary_ft = tf.fit_transform(df1['genre_secondary'])

df1['language'] = df1['language'].fillna('')
language_ft = ohe.fit_transform(df1[['language']])

print(device_type_ft.shape)
print(quality_type_ft.shape)
print(genre_primary_ft.shape)
print(genre_secondary_ft.shape)
print(language_ft.shape)
# Out:
# C:\Users\dhruv.goel1\AppData\Local\Temp\ipykernel_24568\3051993801.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['device_type'] = df1['device_type'].fillna('')
# C:\Users\dhruv.goel1\AppData\Local\Temp\ipykernel_24568\3051993801.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['quality'] = df1['quality'].fillna('')
# C:\Users\dhruv.goel1\AppData\Local\Temp\ipykernel_24568\3051993801.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['genre_primary'] = df1['genre_primary'].fillna('')
# C:\Users\dhruv.goel1\AppData\Local\Temp\ipykernel_24568\3051993801.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['genre_secondary'] = df1['genre_secondary'].fillna('')
# (100000, 5)
# (100000, 4)
# (100000, 21)
# (100000, 21)
# (100000, 8)
# C:\Users\dhruv.goel1\AppData\Local\Temp\ipykernel_24568\3051993801.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['language'] = df1['language'].fillna('')

# %% [markdown]
# ### Binary Feautures True False

# %%
df1['is_netflix_original'] = df1['is_netflix_original'].fillna(False)
df1['is_netflix_original_ft'] = np.where(df1['is_netflix_original'] == True, 1, 0)

df1['content_warning'] = df1['content_warning'].fillna(False)
df1['content_warning_ft'] = np.where(df1['content_warning'] == True, 1, 0)
# Out:
# C:\Users\dhruv.goel1\AppData\Local\Temp\ipykernel_24568\4111502220.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['is_netflix_original'] = df1['is_netflix_original'].fillna(False)
# C:\Users\dhruv.goel1\AppData\Local\Temp\ipykernel_24568\4111502220.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['is_netflix_original_ft'] = np.where(df1['is_netflix_original'] == True, 1, 0)
# C:\Users\dhruv.goel1\AppData\Local\Temp\ipykernel_24568\4111502220.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['content_warning'] = df1['content_warning'].fillna(False)
# C:\Users\dhruv.goel1\AppData\Local\Temp\ipykernel_24568\4111502220.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['content_warning_ft'] = np.where(df1['content_warning'] == True, 1, 0)

# %% [markdown]
# ### Processing Numeric Features

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()


is_netflix_original_ft = sc.fit_transform(df1[['is_netflix_original_ft']])
content_warning_ft = sc.fit_transform(df1[['content_warning_ft']])

df1['duration_minutes'] = df1['duration_minutes'].fillna(np.mean(df1['duration_minutes']))
duration_minutes_ft = sc.fit_transform(df1[['duration_minutes']])
# Out:
# C:\Users\dhruv.goel1\AppData\Local\Temp\ipykernel_24568\1240702503.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['duration_minutes'] = df1['duration_minutes'].fillna(np.mean(df1['duration_minutes']))

# %% [markdown]
# ### Creating Feature Matrix

# %%
#csr for effective row slicing

#giving more weights to genres
from scipy.sparse import hstack

feature_col = hstack([
    device_type_ft,
quality_type_ft,
3*genre_primary_ft,
genre_secondary_ft,
language_ft,is_netflix_original_ft,content_warning_ft,duration_minutes_ft
]).tocsr()

# %%
feature_col.shape
# Out:
# (100000, 62)

# %% [markdown]
# ### User Profile

# %%
def content_based_recommend(user_id): 
    #filtering for a particular user
    user_data = train_df[train_df['user_id'] == user_id]

    liked_movies = user_data[user_data['Final_User_Rating'] >=3]
    
    movie_ids = list(set(user_data['movie_id']))

    #create feature_matrix
    liked = liked_movies.index
    feature_matrix = feature_col[liked,:]
    
    #getting rating matrix
    rating_matrix = liked_movies['Final_User_Rating'].values

    #weighted sum
    weighted_sum = feature_matrix.T @ rating_matrix

    user_profile = weighted_sum / rating_matrix.sum()
    print('User Profile', user_profile)

    #creating 2D vector for cosine similarity
    user_vector = user_profile.reshape(1,-1)
    print('User Vector', user_vector)

    similarity = cosine_similarity(user_vector, feature_col).flatten()

    df1['Sim_Score'] = similarity

    df2 = df1.sort_values(by = ['Sim_Score'], ascending = [False])

    #removing all the movies for the the user
    related_movies = df2[~df2['movie_id'].isin(movie_ids)]

    return related_movies.drop_duplicates(subset = ['movie_id']).head()

# %%
user_id = 'user_06554'
content_based_recommend(user_id)
# Out:
# User Profile [ 0.25396825  0.28042328  0.23280423  0.17460317  0.05820106  0.6031746
#   0.34920635  0.04761905  0.          0.17460317  0.6984127   0.
#   0.          0.58730159  0.          0.17460317  0.          0.17460317
#   0.17460317  0.          0.          0.17460317  0.          0.34920635
#   0.          0.          0.31746032  0.          0.17460317  0.
#   0.          0.11640212  0.          0.          0.          0.
#   0.          0.          0.          0.          0.05611959  0.05820106
#   0.          0.          0.          0.          0.05611959  0.
#   0.          0.          0.05820106  0.65079365  0.11640212  0.05820106
#   0.          0.05820106  0.11640212  0.          0.         -0.15709229
#   0.27717983 -0.25627468]
# User Vector [[ 0.25396825  0.28042328  0.23280423  0.17460317  0.05820106  0.6031746
#    0.34920635  0.04761905  0.          0.17460317  0.6984127   0.
#    0.          0.58730159  0.          0.17460317  0.          0.17460317
#    0.17460317  0.          0.          0.17460317  0.          0.34920635
#    0.          0.          0.31746032  0.          0.17460317  0.
#    0.          0.11640212  0.          0.          0.          0.
#    0.          0.          0.          0.          0.05611959  0.05820106
#    0.          0.          0.          0.          0.05611959  0.
#    0.          0.          0.05820106  0.65079365  0.11640212  0.05820106
#    0.          0.05820106  0.11640212  0.          0.         -0.15709229
#    0.27717983 -0.25627468]]
# C:\Users\dhruv.goel1\AppData\Local\Temp\ipykernel_24568\1194167707.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Sim_Score'] = similarity
#            session_id     user_id    movie_id  watch_date device_type  \
# 83946  session_080684  user_00413  movie_0923  2025-06-07      Laptop
# 49362  session_047453  user_04131  movie_0714  2025-09-17      Laptop
# 68777  session_066119  user_07376  movie_0374  2025-10-10      Laptop
# 44681  session_042967  user_00834  movie_0560  2024-02-18      Laptop
# 90522  session_087026  user_07214  movie_0425  2025-12-05      Laptop
#
#        watch_duration_minutes  progress_percentage     action quality  \
# 83946                   137.6                 25.5    stopped      4K
# 49362                   149.0                 86.7    stopped      4K
# 68777                    52.8                 86.6    started      4K
# 44681                    63.0                  NaN    stopped      4K
# 90522                    30.1                 13.4  completed      4K
#
#       location_country  is_download  user_rating          title  \
# 83946              USA        False          NaN   Last Phoenix
# 49362           Canada        False          NaN    House Dream
# 68777              USA        False          NaN      The Story
# 44681              USA        False          NaN      Ice Queen
# 90522              USA         True          NaN  Storm Kingdom
#
#           content_type genre_primary genre_secondary  release_year  \
# 83946        TV Series     Adventure         Fantasy          1995
# 49362   Limited Series     Adventure         Fantasy          2002
# 68777            Movie     Adventure                          2023
# 44681  Stand-up Comedy     Adventure                          1997
# 90522        TV Series     Adventure                          1994
#
#        duration_minutes rating language country_of_origin  imdb_rating  \
# 83946              45.0  TV-Y7  English               USA          5.7
# 49362              47.0     PG  English               USA          7.0
# 68777             104.0  TV-14  English               USA          7.5
# 44681              51.0   TV-Y  English           Germany          NaN
# 90522              53.0  NC-17  English               USA          NaN
#
#        production_budget  box_office_revenue  number_of_seasons  \
# 83946                NaN                 NaN                4.0
# 49362                NaN                 NaN                7.0
# 68777           766474.0           7301565.0                NaN
# 44681                NaN                 NaN                NaN
# 90522                NaN                 NaN                8.0
#
#        number_of_episodes  is_netflix_original added_to_platform  \
# 83946               182.0                False        2020-08-20
# 49362               108.0                False        2023-11-18
# 68777                 NaN                False        2024-03-05
# 44681                 NaN                False        2025-04-19
# 90522               134.0                False        2023-01-09
#
#        content_warning  is_netflix_original_ft  content_warning_ft  Sim_Score
# 83946             True                       0                   1   0.650868
# 49362             True                       0                   1   0.650447
# 68777             True                       0                   1   0.644256
# 44681            False                       0                   0   0.642737
# 90522            False                       0                   0   0.642245

# %%
df1['user_id'].value_counts()
# Out:
# user_id
# user_06589    23
# user_02666    22
# user_06554    22
# user_05244    22
# user_06474    22
#               ..
# user_08526     2
# user_01600     2
# user_00275     2
# user_06905     2
# user_08159     2
# Name: count, Length: 10000, dtype: int64
